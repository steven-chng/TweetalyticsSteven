# %%
import tweepy

api_key = "drRR4ZPtTuo1N8w7Dj4YznBPe"
api_secrets = "ZrHbFNgEmSI2F6suL8bJenEJbSQv4uFmFkRs4nPaOp0qLamqom"
access_token = "1567774826936340481-1mK8rbsUkU5VhJf9gkqyzm5yipXecU"
access_secret = "sVa3As3vEKwJ4rgDN2kDzt3j8mKJGlP9JJFS7AKqHKRI5"

auth = tweepy.OAuthHandler(api_key, api_secrets)
auth.set_access_token(access_token, access_secret)

api = tweepy.API(auth)

try:
    api.verify_credentials()
    print('Successful Authentication')
except:
    print('Failed authentication')
    
query = "bitcoin"
tweets = api.search_tweets(query, lang = "en", count = 100)

for tweet in tweets:
    polarity = TextBlob(tweet.text).sentiment.polarity
    if (polarity < 0 and polarity > -0.5):
        print("user @: " + str(tweet.user.screen_name))
        print("user followers: "+ str(tweet.user.followers_count))
        print("created at: " + str(tweet.created_at))
        print("tweet text: " + str(tweet.text))
        print("location: " + str(tweet.user.location))
        print("polarity: " + str(polarity))
        print("\n")
# Out:
# Successful Authentication
# user @: BEatris008_
# user followers: 24
# created at: 2022-10-23 21:58:58+00:00
# tweet text: RT @DeFiReb: 🔥Weekend Giveaway Time!!!🔥
#
# 🚀$400 $BTC #bitcoin Total🚀
#
# $200 BTC to a Twitter follower, $200 BTC to one other random person wh…
# location: Hamburg, Germany
# polarity: -0.3125
#
#
# user @: Alerb22440604
# user followers: 611
# created at: 2022-10-23 21:58:58+00:00
# tweet text: RT @AurelienOhayon: #BITCOIN A DROP IS STATISTICALLY EXPECTED.
#
# Descending triangle and volume down.
#
# Inflation drives the market, Bitcoi…
# location:
# polarity: -0.1277777777777778
#
#
# user @: XRP_Loco
# user followers: 151
# created at: 2022-10-23 21:58:55+00:00
# tweet text: RT @CryptoVinco: SEC only went after Ripple/XRP to try to take out Bitcoin and Ethereum’s biggest competition.
#
# Little did they know it wo…
# location:
# polarity: -0.09583333333333333
#
#
# user @: BTCSeeker21
# user followers: 1505
# created at: 2022-10-23 21:58:52+00:00
# tweet text: Watch everyone on #Bitcoin twitter become a weather expert over the next few months
# location: Canada
# polarity: -0.1
#
#
# user @: Alerb22440604
# user followers: 611
# created at: 2022-10-23 21:58:42+00:00
# tweet text: RT @AurelienOhayon: #BITCOIN Volume is down, the stock market is driving the market, inflation is structural.
#
# A final dip is likely. https…
# location:
# polarity: -0.051851851851851864
#
#
# user @: litecoin2142
# user followers: 13
# created at: 2022-10-23 21:58:38+00:00
# tweet text: #Bitcoin All Time Weekly Moving Average (ATWMA)
# 200%    $25,416
# 100%    $ 16,944
#    0%     $8,472       ATWMA
# -25%… https://t.co/XgBFuK5aNq
# location:
# polarity: -0.15
#
#
# user @: Samsquanch69420
# user followers: 161
# created at: 2022-10-23 21:58:28+00:00
# tweet text: @BJusty1 Bitcoin doesn't give a fuck
# location:
# polarity: -0.4
#
#
# user @: Allyismepo
# user followers: 79
# created at: 2022-10-23 21:58:25+00:00
# tweet text: RT @PG_primegames: One of the game mechanics in the game is vending machines with different properties that complement the gameplay
# @LC_PGs…
# location: Republic of the Philippines
# polarity: -0.26666666666666666
#
#
# user @: svnghwoon
# user followers: 366
# created at: 2022-10-23 21:58:23+00:00
# tweet text: RT @PG_primegames: One of the game mechanics in the game is vending machines with different properties that complement the gameplay
# @LC_PGs…
# location: she/her @quaterafterr_ (deact)
# polarity: -0.26666666666666666
#
#
# user @: Tyger1923Crypto
# user followers: 113
# created at: 2022-10-23 21:58:21+00:00
# tweet text: RT @BitcoinMagEDU: The entire 13+ year transaction history of the #bitcoin network fits on a $50 hard drive 💾 https://t.co/FEjSI2OxbL
# location: Brăila, România
# polarity: -0.14583333333333334
#
#
# user @: calmsatoshi
# user followers: 137
# created at: 2022-10-23 21:58:16+00:00
# tweet text: RT @IIICapital: If Bitcoin really starts to rally from here, I think it will be one of its most hated rallies of all time.
#
# Bullish.
# location: Jekyll Island
# polarity: -0.0666666666666667
#
#
# user @: PortugueseOak
# user followers: 112
# created at: 2022-10-23 21:58:09+00:00
# tweet text: RT @TATrader_Alan: #Bitcoin is about to break this tight consolidation.
#
# Price momentum indicator - Coppock Curve
# demostrates similar patte…
# location:
# polarity: -0.08928571428571429
#
#
# user @: mvaslan21
# user followers: 2520
# created at: 2022-10-23 21:58:08+00:00
# tweet text: PLEASE BE CAREFUL BITCOIN PLAYERS I used to be poor, I played leverage, now I'm poorer so I'm poor in Morocco.
# location:
# polarity: -0.3
#
#
# user @: BlazereyesFlow
# user followers: 41
# created at: 2022-10-23 21:58:06+00:00
# tweet text: RT @decodejar: #Bitcoin 1.618 extensions are repeatable and work every single time. It's not a coincidence.  #BTC to ~145k and eventually a…
# location: United States
# polarity: -0.07142857142857142
#
#
# user @: nftoftendotcom
# user followers: 1162
# created at: 2022-10-23 21:58:05+00:00
# tweet text: Bitcoin will surge in 2023 — but be careful what you wish for https://t.co/TfZVxyzCLN https://t.co/HjrNqW055u
# location: United States
# polarity: -0.1
#
#
# user @: dumbwire
# user followers: 29927
# created at: 2022-10-23 21:58:04+00:00
# tweet text: #Bitcoin #BTC #Markets Bitcoin will surge in 2023 — but be careful what you wish for https://t.co/UJJbSFM8ih -… https://t.co/NATZzaVhb0
# location: Houston, TX
# polarity: -0.1
#
#
# user @: 0xdefinews
# user followers: 413
# created at: 2022-10-23 21:58:03+00:00
# tweet text: GM/GA/GN Bitcoin will surge in 2023 — but be careful what you wish for - Cointelegraph https://t.co/oAvGTfivZM
# location:
# polarity: -0.1

# %%
from textblob import TextBlob

text = '''The titular threat of The Blob has always struck me as the ultimate movie
monster: an insatiably hungry, amoeba-like mass able to penetrate
virtually any safeguard, capable of--as a doomed doctor chillingly
describes it--"assimilating flesh on contact.
Snide comparisons to gelatin be damned, it's a concept with the most
devastating of potential consequences, not unlike the grey goo scenario
proposed by technological theorists fearful of
artificial intelligence run rampant.'''

blob = TextBlob(text)
for sentence in blob.sentences:
    print(sentence.sentiment.polarity)
# Out:
# 0.06000000000000001
# -0.34166666666666673
