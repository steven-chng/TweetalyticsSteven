# %%
import tweepy

api_key = "drRR4ZPtTuo1N8w7Dj4YznBPe"
api_secrets = "ZrHbFNgEmSI2F6suL8bJenEJbSQv4uFmFkRs4nPaOp0qLamqom"
access_token = "1567774826936340481-1mK8rbsUkU5VhJf9gkqyzm5yipXecU"
access_secret = "sVa3As3vEKwJ4rgDN2kDzt3j8mKJGlP9JJFS7AKqHKRI5"

auth = tweepy.OAuthHandler(api_key, api_secrets)
auth.set_access_token(access_token, access_secret)

api = tweepy.API(auth)

try:
    api.verify_credentials()
    print('Successful Authentication')
except:
    print('Failed authentication')
    
KEYWORDS = "bitcoin OR python"

tweets = api.search_tweets(KEYWORDS)
print(tweets)
# Out:
# Successful Authentication
# [Status(_api=<tweepy.api.API object at 0x000001F943CD1B70>, _json={'created_at': 'Sun Oct 23 19:11:28 +0000 2022', 'id': 1584261240959881216, 'id_str': '1584261240959881216', 'text': 'RT @DocumentingBTC: #Bitcoin was more stable than the S&amp;P 500 and NASDAQ last month', 'truncated': False, 'entities': {'hashtags': [{'text': 'Bitcoin', 'indices': [20, 28]}], 'symbols': [], 'user_mentions': [{'screen_name': 'DocumentingBTC', 'name': 'Documenting Bitcoin 📄', 'id': 1337780902680809474, 'id_str': '1337780902680809474', 'indices': [3, 18]}], 'urls': []}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 3327279097, 'id_str': '3327279097', 'name': 'YongWorld🌏', 'screen_name': 'yongworld2', 'location': 'Ilorin, Nigeria', 'description': 'JUST ARSENAL.🌏\n🌏 $BTC price. \n#BTC ,Ethereum,LiteCoin,Doge,USDT and all Country GiftCards needed with fast payment 🔥🔥🔥', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 78, 'friends_count': 376, 'listed_count': 0, 'created_at': 'Sun Aug 23 21:20:29 +0000 2015', 'favourites_count': 3729, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 3858, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1582873523739136001/lD3QQZCr_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1582873523739136001/lD3QQZCr_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3327279097/1664315486', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': True, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none', 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Sun Oct 23 18:31:02 +0000 2022', 'id': 1584251064982724609, 'id_str': '1584251064982724609', 'text': '#Bitcoin was more stable than the S&amp;P 500 and NASDAQ last month', 'truncated': False, 'entities': {'hashtags': [{'text': 'Bitcoin', 'indices': [0, 8]}], 'symbols': [], 'user_mentions': [], 'urls': []}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1337780902680809474, 'id_str': '1337780902680809474', 'name': 'Documenting Bitcoin 📄', 'screen_name': 'DocumentingBTC', 'location': '', 'description': '“It might make sense just to get some in case it catches on. If enough people think the same way, that becomes a self fulfilling prophecy” — Satoshi Nakamoto', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 836178, 'friends_count': 1642, 'listed_count': 6351, 'created_at': 'Sat Dec 12 15:26:42 +0000 2020', 'favourites_count': 22783, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 5605, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled' ...
